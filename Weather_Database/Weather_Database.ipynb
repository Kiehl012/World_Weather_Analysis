# %%
import requests
import json
from config import g_key
from config import weather_api_key
import numpy as np
import random
import pandas as pd
from citipy import citipy
import time

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
len(coordinates)
# Out:
# 2000

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 759

# %%
city_api_data = []
base_url = "Http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+weather_api_key
record_count = 1
set_count = 1
skipped_cities = 0

print("Beginning Data Retrieval     ")
print("-----------------------------") 

for i,city in enumerate(cities):
   
    if (i % 50 == 0 and record_count >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    new_url = f"{base_url}&q={city.replace(' ','+')}"
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1 
    
    try: 
        data = requests.get(new_url).json()
        country = data['sys']['country']
        city_lat = data['coord']['lat']
        city_lng = data['coord']['lon']
        max_temp = data['main']['temp_max']
        humidity = data['main']['humidity']
        cloudiness = data['clouds']['all']
        wind = data['wind']['speed']
        weather_description = data['weather'][0]['description']
        city_api_data.append({'City': city.title(),
                              'Country': country,
                              'Lat': city_lat,
                              'Lng': city_lng,
                              'Max Temp': max_temp,
                              '% Humidity': humidity,
                              '% Cloudiness': cloudiness,
                              'Wind Speed': wind,
                              'Weather Desciption': weather_description})
    except:
        print("Missing data or missing city...skipping city")
        skipped_cities += 1
        pass
    

print("-"*20)
print(f'Data pull complete. {skipped_cities} cities were skipped.')
print("-"*20)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hambantota
# Processing Record 2 of Set 1 | lingyuan
# Processing Record 3 of Set 1 | hasaki
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | tilichiki
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | abu dhabi
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | palabuhanratu
# Missing data or missing city...skipping city
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | lorengau
# Processing Record 17 of Set 1 | belushya guba
# Missing data or missing city...skipping city
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | teo
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | alta floresta
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | grand gaube
# Processing Record 24 of Set 1 | adrar
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | punto fijo
# Processing Record 27 of Set 1 | illoqqortoormiut
# Missing data or missing city...skipping city
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | thinadhoo
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | pavlodar
# Processing Record 34 of Set 1 | ust-kamchatsk
# Missing data or missing city...skipping city
# Processing Record 35 of Set 1 | tezze sul brenta
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | bacuit
# Missing data or missing city...skipping city
# Processing Record 39 of Set 1 | morondava
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | yangambi
# Processing Record 42 of Set 1 | gat
# Processing Record 43 of Set 1 | ukiah
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | nuuk
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | usinsk
# Processing Record 48 of Set 1 | kingston
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | chuy
# Processing Record 1 of Set 2 | san cristobal
# Processing Record 2 of Set 2 | destin
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | lazaro cardenas
# Processing Record 5 of Set 2 | bud
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | mersing
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | kavaratti
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | seoul
# Processing Record 13 of Set 2 | lomza
# Processing Record 14 of Set 2 | arona
# Processing Record 15 of Set 2 | fairbanks
# Processing Record 16 of Set 2 | inhambane
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | poltavka
# Processing Record 19 of Set 2 | guerrero negro
# Processing Record 20 of Set 2 | severo-kurilsk
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | uwayl
# Missing data or missing city...skipping city
# Processing Record 23 of Set 2 | codrington
# Processing Record 24 of Set 2 | batagay-alyta
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | rumonge
# Processing Record 27 of Set 2 | ibra
# Processing Record 28 of Set 2 | cidreira
# Processing Record 29 of Set 2 | kurdzhinovo
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | ust-tsilma
# Processing Record 32 of Set 2 | biskamzha
# Processing Record 33 of Set 2 | longyearbyen
# Processing Record 34 of Set 2 | vaitupu
# Missing data or missing city...skipping city
# Processing Record 35 of Set 2 | sitka
# Processing Record 36 of Set 2 | sentyabrskiy
# Missing data or missing city...skipping city
# Processing Record 37 of Set 2 | lata
# Processing Record 38 of Set 2 | mapastepec
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | rundu
# Processing Record 41 of Set 2 | meulaboh
# Processing Record 42 of Set 2 | attawapiskat
# Missing data or missing city...skipping city
# Processing Record 43 of Set 2 | sao filipe
# Processing Record 44 of Set 2 | yakima
# Processing Record 45 of Set 2 | vostok
# Processing Record 46 of Set 2 | axim
# Processing Record 47 of Set 2 | fortuna
# Processing Record 48 of Set 2 | hobart
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | tulca
# Processing Record 1 of Set 3 | najran
# Processing Record 2 of Set 3 | poronaysk
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | pisco
# Processing Record 5 of Set 3 | turukhansk
# Processing Record 6 of Set 3 | chokurdakh
# Processing Record 7 of Set 3 | palmas
# Processing Record 8 of Set 3 | kovur
# Processing Record 9 of Set 3 | atasu
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | zalesovo
# Processing Record 12 of Set 3 | nizhneyansk
# Missing data or missing city...skipping city
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | havoysund
# Processing Record 15 of Set 3 | andenes
# Processing Record 16 of Set 3 | yeppoon
# Processing Record 17 of Set 3 | nicoya
# Processing Record 18 of Set 3 | saleaula
# Missing data or missing city...skipping city
# Processing Record 19 of Set 3 | zhangye
# Processing Record 20 of Set 3 | kloulklubed
# Processing Record 21 of Set 3 | whitehorse
# Processing Record 22 of Set 3 | taolanaro
# Missing data or missing city...skipping city
# Processing Record 23 of Set 3 | pangnirtung
# Processing Record 24 of Set 3 | urazovo
# Processing Record 25 of Set 3 | champerico
# Processing Record 26 of Set 3 | alta
# Processing Record 27 of Set 3 | cape town
# Processing Record 28 of Set 3 | touros
# Processing Record 29 of Set 3 | cabo san lucas
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | kununurra
# Processing Record 32 of Set 3 | namibe
# Processing Record 33 of Set 3 | isangel
# Processing Record 34 of Set 3 | sataua
# Missing data or missing city...skipping city
# Processing Record 35 of Set 3 | jizan
# Processing Record 36 of Set 3 | barentsburg
# Missing data or missing city...skipping city
# Processing Record 37 of Set 3 | colares
# Processing Record 38 of Set 3 | le port
# Processing Record 39 of Set 3 | semnan
# Processing Record 40 of Set 3 | hofn
# Processing Record 41 of Set 3 | ivanishchi
# Processing Record 42 of Set 3 | urcos
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | oyama
# Processing Record 45 of Set 3 | mount isa
# Processing Record 46 of Set 3 | deputatskiy
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | wulanhaote
# Missing data or missing city...skipping city
# Processing Record 49 of Set 3 | charlestown
# Processing Record 50 of Set 3 | martinsville
# Processing Record 1 of Set 4 | dongsheng
# Processing Record 2 of Set 4 | sofiysk
# Missing data or missing city...skipping city
# Processing Record 3 of Set 4 | mishkino
# Processing Record 4 of Set 4 | kamenskoye
# Missing data or missing city...skipping city
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | san patricio
# Processing Record 7 of Set 4 | pekan
# Processing Record 8 of Set 4 | tlahualilo
# Missing data or missing city...skipping city
# Processing Record 9 of Set 4 | blagoyevo
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | charters towers
# Processing Record 12 of Set 4 | preobrazheniye
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | labuhan
# Processing Record 15 of Set 4 | pyay
# Processing Record 16 of Set 4 | boyolangu
# Processing Record 17 of Set 4 | hurghada
# Processing Record 18 of Set 4 | ust-kut
# Processing Record 19 of Set 4 | huntingdon
# Processing Record 20 of Set 4 | ahipara
# Processing Record 21 of Set 4 | ilulissat
# Processing Record 22 of Set 4 | luderitz
# Processing Record 23 of Set 4 | port hardy
# Processing Record 24 of Set 4 | faya
# Processing Record 25 of Set 4 | alipur duar
# Missing data or missing city...skipping city
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | svarstad
# Processing Record 28 of Set 4 | owando
# Processing Record 29 of Set 4 | fort nelson
# Processing Record 30 of Set 4 | chimbote
# Processing Record 31 of Set 4 | eureka
# Processing Record 32 of Set 4 | sao joao da barra
# Processing Record 33 of Set 4 | yaan
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | dzoragyukh
# Missing data or missing city...skipping city
# Processing Record 36 of Set 4 | kamaishi
# Processing Record 37 of Set 4 | wahiawa
# Processing Record 38 of Set 4 | falkenberg
# Processing Record 39 of Set 4 | bredasdorp
# Processing Record 40 of Set 4 | altay
# Processing Record 41 of Set 4 | ormara
# Processing Record 42 of Set 4 | nouadhibou
# Processing Record 43 of Set 4 | areia branca
# Processing Record 44 of Set 4 | kimbe
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | nalut
# Processing Record 47 of Set 4 | dunedin
# Processing Record 48 of Set 4 | xudat
# Processing Record 49 of Set 4 | samana
# Processing Record 50 of Set 4 | chapais
# Processing Record 1 of Set 5 | zhongshu
# Processing Record 2 of Set 5 | pokhara
# Processing Record 3 of Set 5 | katsuura
# Processing Record 4 of Set 5 | dennery
# Processing Record 5 of Set 5 | hoa binh
# Processing Record 6 of Set 5 | cherskiy
# Processing Record 7 of Set 5 | amudalavalasa
# Processing Record 8 of Set 5 | gurgan
# Missing data or missing city...skipping city
# Processing Record 9 of Set 5 | uniao da victoria
# Missing data or missing city...skipping city
# Processing Record 10 of Set 5 | leningradskiy
# Processing Record 11 of Set 5 | saint-joseph
# Processing Record 12 of Set 5 | beyneu
# Processing Record 13 of Set 5 | fuerte olimpo
# Processing Record 14 of Set 5 | zhigansk
# Processing Record 15 of Set 5 | gornopravdinsk
# Processing Record 16 of Set 5 | mareeba
# Processing Record 17 of Set 5 | acapulco
# Processing Record 18 of Set 5 | pedernales
# Processing Record 19 of Set 5 | takaungu
# Processing Record 20 of Set 5 | hershey
# Processing Record 21 of Set 5 | saldanha
# Processing Record 22 of Set 5 | shasta lake
# Processing Record 23 of Set 5 | richards bay
# Processing Record 24 of Set 5 | ternate
# Processing Record 25 of Set 5 | teguldet
# Processing Record 26 of Set 5 | sibolga
# Processing Record 27 of Set 5 | belmonte
# Processing Record 28 of Set 5 | talnakh
# Processing Record 29 of Set 5 | batticaloa
# Processing Record 30 of Set 5 | malkara
# Processing Record 31 of Set 5 | geraldton
# Processing Record 32 of Set 5 | amarwara
# Processing Record 33 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 5 | coolum beach
# Processing Record 35 of Set 5 | new norfolk
# Processing Record 36 of Set 5 | ulaangom
# Processing Record 37 of Set 5 | saint-leu
# Processing Record 38 of Set 5 | los algarrobos
# Processing Record 39 of Set 5 | esperance
# Processing Record 40 of Set 5 | pundaguitan
# Processing Record 41 of Set 5 | satitoa
# Missing data or missing city...skipping city
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | agadez
# Processing Record 44 of Set 5 | mocuba
# Processing Record 45 of Set 5 | rio cuarto
# Processing Record 46 of Set 5 | bethel
# Processing Record 47 of Set 5 | kollumerland
# Missing data or missing city...skipping city
# Processing Record 48 of Set 5 | asau
# Processing Record 49 of Set 5 | lubango
# Processing Record 50 of Set 5 | prince george
# Processing Record 1 of Set 6 | daitari
# Processing Record 2 of Set 6 | klaksvik
# Processing Record 3 of Set 6 | johnshaven
# Processing Record 4 of Set 6 | yatou
# Processing Record 5 of Set 6 | cochrane
# Processing Record 6 of Set 6 | lagoa
# Processing Record 7 of Set 6 | prince rupert
# Processing Record 8 of Set 6 | bjornevatn
# Processing Record 9 of Set 6 | vardo
# Processing Record 10 of Set 6 | morro bay
# Processing Record 11 of Set 6 | vestmanna
# Processing Record 12 of Set 6 | kazerun
# Processing Record 13 of Set 6 | chillicothe
# Processing Record 14 of Set 6 | basse
# Processing Record 15 of Set 6 | alofi
# Processing Record 16 of Set 6 | kazalinsk
# Missing data or missing city...skipping city
# Processing Record 17 of Set 6 | nadym
# Processing Record 18 of Set 6 | torbay
# Processing Record 19 of Set 6 | camocim
# Processing Record 20 of Set 6 | boralday
# Processing Record 21 of Set 6 | burica
# Missing data or missing city...skipping city
# Processing Record 22 of Set 6 | kuopio
# Processing Record 23 of Set 6 | broome
# Processing Record 24 of Set 6 | vernon
# Processing Record 25 of Set 6 | bolungarvik
# Missing data or missing city...skipping city
# Processing Record 26 of Set 6 | kavieng
# Processing Record 27 of Set 6 | serebryanyy bor
# Processing Record 28 of Set 6 | port alfred
# Processing Record 29 of Set 6 | salalah
# Processing Record 30 of Set 6 | mola di bari
# Processing Record 31 of Set 6 | yulara
# Processing Record 32 of Set 6 | luau
# Processing Record 33 of Set 6 | kingman
# Processing Record 34 of Set 6 | la ronge
# Processing Record 35 of Set 6 | panguna
# Processing Record 36 of Set 6 | umzimvubu
# Missing data or missing city...skipping city
# Processing Record 37 of Set 6 | yantal
# Processing Record 38 of Set 6 | bam
# Processing Record 39 of Set 6 | general roca
# Processing Record 40 of Set 6 | taltal
# Processing Record 41 of Set 6 | norman wells
# Processing Record 42 of Set 6 | nome
# Processing Record 43 of Set 6 | souillac
# Processing Record 44 of Set 6 | kiama
# Processing Record 45 of Set 6 | shiyan
# Processing Record 46 of Set 6 | waddan
# Processing Record 47 of Set 6 | bafq
# Processing Record 48 of Set 6 | thunder bay
# Processing Record 49 of Set 6 | zaraza
# Processing Record 50 of Set 6 | mount gambier
# Processing Record 1 of Set 7 | porto novo
# Processing Record 2 of Set 7 | nemuro
# Processing Record 3 of Set 7 | kemijarvi
# Processing Record 4 of Set 7 | bokspits
# Missing data or missing city...skipping city
# Processing Record 5 of Set 7 | kapiri mposhi
# Processing Record 6 of Set 7 | madisonville
# Processing Record 7 of Set 7 | ust-kuyga
# Processing Record 8 of Set 7 | meiganga
# Processing Record 9 of Set 7 | mukhen
# Processing Record 10 of Set 7 | port elizabeth
# Processing Record 11 of Set 7 | mount pleasant
# Processing Record 12 of Set 7 | elko
# Processing Record 13 of Set 7 | kysyl-syr
# Processing Record 14 of Set 7 | padang
# Processing Record 15 of Set 7 | arman
# Processing Record 16 of Set 7 | haines junction
# Processing Record 17 of Set 7 | celestun
# Processing Record 18 of Set 7 | fort-shevchenko
# Processing Record 19 of Set 7 | junagarh
# Processing Record 20 of Set 7 | sioux lookout
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | kupang
# Processing Record 23 of Set 7 | tornio
# Processing Record 24 of Set 7 | kahului
# Processing Record 25 of Set 7 | westport
# Processing Record 26 of Set 7 | samusu
# Missing data or missing city...skipping city
# Processing Record 27 of Set 7 | moen
# Processing Record 28 of Set 7 | grindavik
# Processing Record 29 of Set 7 | nantucket
# Processing Record 30 of Set 7 | kuche
# Missing data or missing city...skipping city
# Processing Record 31 of Set 7 | warqla
# Missing data or missing city...skipping city
# Processing Record 32 of Set 7 | harnai
# Processing Record 33 of Set 7 | visavadar
# Processing Record 34 of Set 7 | kirando
# Processing Record 35 of Set 7 | benin
# Processing Record 36 of Set 7 | okhotsk
# Processing Record 37 of Set 7 | los llanos de aridane
# Processing Record 38 of Set 7 | solovetskiy
# Missing data or missing city...skipping city
# Processing Record 39 of Set 7 | mana
# Processing Record 40 of Set 7 | progreso
# Processing Record 41 of Set 7 | conceicao do araguaia
# Processing Record 42 of Set 7 | kaeo
# Processing Record 43 of Set 7 | masvingo
# Processing Record 44 of Set 7 | sao desiderio
# Processing Record 45 of Set 7 | hailey
# Processing Record 46 of Set 7 | carcasi
# Processing Record 47 of Set 7 | barranca
# Processing Record 48 of Set 7 | avarua
# Processing Record 49 of Set 7 | mexico
# Processing Record 50 of Set 7 | sao jose da coroa grande
# Processing Record 1 of Set 8 | mugumu
# Processing Record 2 of Set 8 | nongpoh
# Processing Record 3 of Set 8 | riachao das neves
# Processing Record 4 of Set 8 | bentiu
# Processing Record 5 of Set 8 | korla
# Processing Record 6 of Set 8 | tadine
# Processing Record 7 of Set 8 | roberval
# Processing Record 8 of Set 8 | olafsvik
# Processing Record 9 of Set 8 | sarangani
# Processing Record 10 of Set 8 | portland
# Processing Record 11 of Set 8 | bulgan
# Processing Record 12 of Set 8 | amparafaravola
# Processing Record 13 of Set 8 | necochea
# Processing Record 14 of Set 8 | port macquarie
# Processing Record 15 of Set 8 | port blair
# Processing Record 16 of Set 8 | nikolskoye
# Processing Record 17 of Set 8 | matara
# Processing Record 18 of Set 8 | saint-augustin
# Processing Record 19 of Set 8 | tanout
# Processing Record 20 of Set 8 | marysville
# Processing Record 21 of Set 8 | zemio
# Processing Record 22 of Set 8 | jambi
# Processing Record 23 of Set 8 | grand-santi
# Processing Record 24 of Set 8 | ust-omchug
# Processing Record 25 of Set 8 | astoria
# Processing Record 26 of Set 8 | puerto escondido
# Processing Record 27 of Set 8 | puerto del rosario
# Processing Record 28 of Set 8 | bandarbeyla
# Processing Record 29 of Set 8 | yarada
# Processing Record 30 of Set 8 | ngukurr
# Missing data or missing city...skipping city
# Processing Record 31 of Set 8 | grand river south east
# Missing data or missing city...skipping city
# Processing Record 32 of Set 8 | bengkulu
# Processing Record 33 of Set 8 | milingimbi
# Missing data or missing city...skipping city
# Processing Record 34 of Set 8 | sistranda
# Processing Record 35 of Set 8 | luwuk
# Processing Record 36 of Set 8 | gari
# Processing Record 37 of Set 8 | nyimba
# Processing Record 38 of Set 8 | remetea mare
# Processing Record 39 of Set 8 | jian
# Processing Record 40 of Set 8 | gravdal
# Processing Record 41 of Set 8 | burlington
# Processing Record 42 of Set 8 | san policarpo
# Processing Record 43 of Set 8 | vallenar
# Processing Record 44 of Set 8 | saint-esteve
# Processing Record 45 of Set 8 | sturgeon falls
# Processing Record 46 of Set 8 | yinchuan
# Processing Record 47 of Set 8 | creston
# Processing Record 48 of Set 8 | chantada
# Processing Record 49 of Set 8 | scottsbluff
# Processing Record 50 of Set 8 | tiksi
# Processing Record 1 of Set 9 | tsihombe
# Missing data or missing city...skipping city
# Processing Record 2 of Set 9 | beberibe
# Processing Record 3 of Set 9 | lolua
# Missing data or missing city...skipping city
# Processing Record 4 of Set 9 | constitucion
# Processing Record 5 of Set 9 | porto walter
# Processing Record 6 of Set 9 | fomboni
# Processing Record 7 of Set 9 | vao
# Processing Record 8 of Set 9 | huanren
# Processing Record 9 of Set 9 | tasbuget
# Missing data or missing city...skipping city
# Processing Record 10 of Set 9 | pevek
# Processing Record 11 of Set 9 | kegayli
# Missing data or missing city...skipping city
# Processing Record 12 of Set 9 | xining
# Processing Record 13 of Set 9 | hayato
# Missing data or missing city...skipping city
# Processing Record 14 of Set 9 | roros
# Processing Record 15 of Set 9 | mvuma
# Processing Record 16 of Set 9 | ossora
# Processing Record 17 of Set 9 | maceio
# Processing Record 18 of Set 9 | victoria
# Processing Record 19 of Set 9 | monterey
# Processing Record 20 of Set 9 | ban phai
# Processing Record 21 of Set 9 | iqaluit
# Processing Record 22 of Set 9 | harper
# Processing Record 23 of Set 9 | eyrarbakki
# Processing Record 24 of Set 9 | lichuan
# Processing Record 25 of Set 9 | lebedinyy
# Processing Record 26 of Set 9 | suwalki
# Processing Record 27 of Set 9 | sinzheim
# Processing Record 28 of Set 9 | manzhouli
# Processing Record 29 of Set 9 | praia da vitoria
# Processing Record 30 of Set 9 | port moresby
# Processing Record 31 of Set 9 | sawtell
# Processing Record 32 of Set 9 | flinders
# Processing Record 33 of Set 9 | mys shmidta
# Missing data or missing city...skipping city
# Processing Record 34 of Set 9 | jijiga
# Processing Record 35 of Set 9 | tuatapere
# Processing Record 36 of Set 9 | yumen
# Processing Record 37 of Set 9 | sikandarpur
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | kyra
# Processing Record 40 of Set 9 | labutta
# Missing data or missing city...skipping city
# Processing Record 41 of Set 9 | wazzan
# Missing data or missing city...skipping city
# Processing Record 42 of Set 9 | haibowan
# Missing data or missing city...skipping city
# Processing Record 43 of Set 9 | salinas
# Processing Record 44 of Set 9 | troina
# Processing Record 45 of Set 9 | biak
# Processing Record 46 of Set 9 | anadyr
# Processing Record 47 of Set 9 | belyy yar
# Processing Record 48 of Set 9 | iberia
# Processing Record 49 of Set 9 | manapparai
# Processing Record 50 of Set 9 | nanga eboko
# Processing Record 1 of Set 10 | faanui
# Processing Record 2 of Set 10 | terra santa
# Processing Record 3 of Set 10 | crab hill
# Missing data or missing city...skipping city
# Processing Record 4 of Set 10 | cabiraoan
# Processing Record 5 of Set 10 | tawkar
# Missing data or missing city...skipping city
# Processing Record 6 of Set 10 | sinnamary
# Processing Record 7 of Set 10 | pendleton
# Processing Record 8 of Set 10 | novoagansk
# Processing Record 9 of Set 10 | berlevag
# Processing Record 10 of Set 10 | abu kamal
# Processing Record 11 of Set 10 | dmitrovsk-orlovskiy
# Processing Record 12 of Set 10 | amilly
# Processing Record 13 of Set 10 | joshimath
# Processing Record 14 of Set 10 | santa rosa
# Processing Record 15 of Set 10 | aksarka
# Processing Record 16 of Set 10 | diffa
# Processing Record 17 of Set 10 | burla
# Processing Record 18 of Set 10 | comodoro rivadavia
# Processing Record 19 of Set 10 | ranong
# Processing Record 20 of Set 10 | amahai
# Processing Record 21 of Set 10 | amuntai
# Processing Record 22 of Set 10 | komsomolskiy
# Processing Record 23 of Set 10 | bagdarin
# Processing Record 24 of Set 10 | gao
# Processing Record 25 of Set 10 | oksfjord
# Processing Record 26 of Set 10 | marawi
# Processing Record 27 of Set 10 | kasongo-lunda
# Processing Record 28 of Set 10 | buala
# Processing Record 29 of Set 10 | phalodi
# Processing Record 30 of Set 10 | surgut
# Processing Record 31 of Set 10 | camana
# Processing Record 32 of Set 10 | piombino
# Processing Record 33 of Set 10 | mineiros
# Processing Record 34 of Set 10 | kruisfontein
# Processing Record 35 of Set 10 | petrolina
# Processing Record 36 of Set 10 | kalawit
# Processing Record 37 of Set 10 | ketchikan
# Processing Record 38 of Set 10 | lompoc
# Processing Record 39 of Set 10 | atar
# Processing Record 40 of Set 10 | ringsted
# Processing Record 41 of Set 10 | voznesenye
# Processing Record 42 of Set 10 | tirumullaivasal
# Processing Record 43 of Set 10 | bridlington
# Processing Record 44 of Set 10 | jacobina
# Processing Record 45 of Set 10 | kudahuvadhoo
# Processing Record 46 of Set 10 | cabra
# Processing Record 47 of Set 10 | santa maria
# Processing Record 48 of Set 10 | shimoda
# Processing Record 49 of Set 10 | san angelo
# Processing Record 50 of Set 10 | bathsheba
# Processing Record 1 of Set 11 | san rafael
# Processing Record 2 of Set 11 | kashi
# Processing Record 3 of Set 11 | dolbeau
# Missing data or missing city...skipping city
# Processing Record 4 of Set 11 | lufilufi
# Processing Record 5 of Set 11 | eskasem
# Missing data or missing city...skipping city
# Processing Record 6 of Set 11 | soyo
# Processing Record 7 of Set 11 | beira
# Processing Record 8 of Set 11 | sorvag
# Missing data or missing city...skipping city
# Processing Record 9 of Set 11 | guntakal
# Processing Record 10 of Set 11 | punuare
# Processing Record 11 of Set 11 | babu
# Processing Record 12 of Set 11 | gelemso
# Processing Record 13 of Set 11 | bilma
# Processing Record 14 of Set 11 | boali
# Processing Record 15 of Set 11 | vestbygda
# Missing data or missing city...skipping city
# Processing Record 16 of Set 11 | tucuma
# Processing Record 17 of Set 11 | chute-aux-outardes
# Processing Record 18 of Set 11 | huarmey
# Processing Record 19 of Set 11 | sidney
# Processing Record 20 of Set 11 | skjervoy
# Processing Record 21 of Set 11 | luis correia
# Processing Record 22 of Set 11 | barcelona
# Processing Record 23 of Set 11 | roma
# Processing Record 24 of Set 11 | papillion
# Processing Record 25 of Set 11 | mecca
# Processing Record 26 of Set 11 | mandera
# Processing Record 27 of Set 11 | tura
# Processing Record 28 of Set 11 | la asuncion
# Processing Record 29 of Set 11 | aasiaat
# Processing Record 30 of Set 11 | bari
# Processing Record 31 of Set 11 | bakchar
# Processing Record 32 of Set 11 | mastic beach
# Processing Record 33 of Set 11 | port lincoln
# Processing Record 34 of Set 11 | naze
# Processing Record 35 of Set 11 | pareora
# Processing Record 36 of Set 11 | maniitsoq
# Processing Record 37 of Set 11 | sydney
# Processing Record 38 of Set 11 | rovaniemi
# Processing Record 39 of Set 11 | dubbo
# Processing Record 40 of Set 11 | hatton
# Processing Record 41 of Set 11 | pangai
# Processing Record 42 of Set 11 | sakaiminato
# Processing Record 43 of Set 11 | sur
# Processing Record 44 of Set 11 | bonfim
# Processing Record 45 of Set 11 | kibaya
# Processing Record 46 of Set 11 | tam ky
# Processing Record 47 of Set 11 | quatre cocos
# Processing Record 48 of Set 11 | iquique
# Processing Record 49 of Set 11 | rochester
# Processing Record 50 of Set 11 | boende
# Processing Record 1 of Set 12 | liancheng
# Processing Record 2 of Set 12 | paramonga
# Processing Record 3 of Set 12 | urdzhar
# Missing data or missing city...skipping city
# Processing Record 4 of Set 12 | zhangjiakou
# Processing Record 5 of Set 12 | yusva
# Missing data or missing city...skipping city
# Processing Record 6 of Set 12 | poum
# Processing Record 7 of Set 12 | utiroa
# Missing data or missing city...skipping city
# Processing Record 8 of Set 12 | miranda
# Processing Record 9 of Set 12 | dolores
# Processing Record 10 of Set 12 | gizo
# Processing Record 11 of Set 12 | momcilgrad
# Missing data or missing city...skipping city
# Processing Record 12 of Set 12 | traunstein
# Processing Record 13 of Set 12 | verkhnyaya inta
# Processing Record 14 of Set 12 | salym
# Processing Record 15 of Set 12 | san luis
# Processing Record 16 of Set 12 | oriximina
# Processing Record 17 of Set 12 | kabanjahe
# Processing Record 18 of Set 12 | emba
# Processing Record 19 of Set 12 | cairns
# Processing Record 20 of Set 12 | margate
# Processing Record 21 of Set 12 | ixtapa
# Processing Record 22 of Set 12 | madawaska
# Processing Record 23 of Set 12 | hidrolandia
# Processing Record 24 of Set 12 | puri
# Processing Record 25 of Set 12 | launceston
# Processing Record 26 of Set 12 | scottsburgh
# Missing data or missing city...skipping city
# Processing Record 27 of Set 12 | nelson bay
# Processing Record 28 of Set 12 | ilinge
# Processing Record 29 of Set 12 | smithers
# Processing Record 30 of Set 12 | samalaeulu
# Missing data or missing city...skipping city
# Processing Record 31 of Set 12 | oudtshoorn
# Processing Record 32 of Set 12 | suba
# Processing Record 33 of Set 12 | urucui
# Processing Record 34 of Set 12 | tautira
# Processing Record 35 of Set 12 | jiuquan
# Processing Record 36 of Set 12 | meyungs
# Missing data or missing city...skipping city
# Processing Record 37 of Set 12 | buraydah
# Processing Record 38 of Set 12 | jalu
# Processing Record 39 of Set 12 | pemba
# Processing Record 40 of Set 12 | manavalakurichi
# Processing Record 41 of Set 12 | nanortalik
# Processing Record 42 of Set 12 | el balyana
# Missing data or missing city...skipping city
# Processing Record 43 of Set 12 | tokmak
# Processing Record 44 of Set 12 | taree
# Processing Record 45 of Set 12 | hamilton
# Processing Record 46 of Set 12 | boddam
# Processing Record 47 of Set 12 | ulaanbaatar
# Processing Record 48 of Set 12 | cockburn harbour
# Missing data or missing city...skipping city
# Processing Record 49 of Set 12 | nara
# Processing Record 50 of Set 12 | alexandria
# Processing Record 1 of Set 13 | abu samrah
# Processing Record 2 of Set 13 | port augusta
# Processing Record 3 of Set 13 | srednekolymsk
# Processing Record 4 of Set 13 | chapleau
# Processing Record 5 of Set 13 | the valley
# Processing Record 6 of Set 13 | murgab
# Processing Record 7 of Set 13 | nabire
# Processing Record 8 of Set 13 | college
# Processing Record 9 of Set 13 | banamba
# Processing Record 10 of Set 13 | badarganj
# Processing Record 11 of Set 13 | de aar
# Processing Record 12 of Set 13 | sorland
# Processing Record 13 of Set 13 | wanning
# Processing Record 14 of Set 13 | kytlym
# Missing data or missing city...skipping city
# Processing Record 15 of Set 13 | blackfoot
# Processing Record 16 of Set 13 | itoman
# Processing Record 17 of Set 13 | henties bay
# Processing Record 18 of Set 13 | puerto el triunfo
# Processing Record 19 of Set 13 | nishihara
# Processing Record 20 of Set 13 | andijon
# Processing Record 21 of Set 13 | turayf
# Processing Record 22 of Set 13 | tupiza
# Processing Record 23 of Set 13 | ucluelet
# Processing Record 24 of Set 13 | sorong
# Processing Record 25 of Set 13 | coruripe
# Processing Record 26 of Set 13 | kasama
# Processing Record 27 of Set 13 | shubarshi
# Processing Record 28 of Set 13 | kyzyl-suu
# Processing Record 29 of Set 13 | marzuq
# Processing Record 30 of Set 13 | kirakira
# Processing Record 31 of Set 13 | hualmay
# Processing Record 32 of Set 13 | dipkarpaz
# Missing data or missing city...skipping city
# Processing Record 33 of Set 13 | dunda
# Processing Record 34 of Set 13 | lavrentiya
# Processing Record 35 of Set 13 | tenenkou
# Processing Record 36 of Set 13 | lulea
# Processing Record 37 of Set 13 | viligili
# Missing data or missing city...skipping city
# Processing Record 38 of Set 13 | nouakchott
# Processing Record 39 of Set 13 | batagay
# Processing Record 40 of Set 13 | saint-pierre
# Processing Record 41 of Set 13 | ozgon
# Missing data or missing city...skipping city
# Processing Record 42 of Set 13 | teya
# Processing Record 43 of Set 13 | slave lake
# Processing Record 44 of Set 13 | vestmannaeyjar
# Processing Record 45 of Set 13 | balakhta
# Processing Record 46 of Set 13 | keetmanshoop
# Processing Record 47 of Set 13 | popondetta
# Processing Record 48 of Set 13 | khandyga
# Processing Record 49 of Set 13 | iracoubo
# Processing Record 50 of Set 13 | rio grande
# Processing Record 1 of Set 14 | merauke
# Processing Record 2 of Set 14 | coquimbo
# Processing Record 3 of Set 14 | hobyo
# Processing Record 4 of Set 14 | pacific grove
# Processing Record 5 of Set 14 | coos bay
# Processing Record 6 of Set 14 | cherdyn
# Processing Record 7 of Set 14 | beloha
# Processing Record 8 of Set 14 | nagykanizsa
# Processing Record 9 of Set 14 | sterling
# Processing Record 10 of Set 14 | polyarnyy
# Processing Record 11 of Set 14 | pitanga
# Processing Record 12 of Set 14 | lihula
# Processing Record 13 of Set 14 | winona
# Processing Record 14 of Set 14 | rawson
# Processing Record 15 of Set 14 | kutum
# Processing Record 16 of Set 14 | puerto narino
# Processing Record 17 of Set 14 | nanchong
# Processing Record 18 of Set 14 | ladovskaya balka
# Processing Record 19 of Set 14 | gorele
# Processing Record 20 of Set 14 | akyab
# Processing Record 21 of Set 14 | mogadishu
# Processing Record 22 of Set 14 | dingle
# Processing Record 23 of Set 14 | ankazoabo
# Processing Record 24 of Set 14 | neryungri
# Processing Record 25 of Set 14 | biltine
# Processing Record 26 of Set 14 | mwense
# Processing Record 27 of Set 14 | urumqi
# Processing Record 28 of Set 14 | havre-saint-pierre
# Processing Record 29 of Set 14 | terrace bay
# Processing Record 30 of Set 14 | karratha
# Processing Record 31 of Set 14 | marcona
# Missing data or missing city...skipping city
# Processing Record 32 of Set 14 | caravelas
# Processing Record 33 of Set 14 | andarab
# Missing data or missing city...skipping city
# Processing Record 34 of Set 14 | piranhas
# Processing Record 35 of Set 14 | san quintin
# Processing Record 36 of Set 14 | mackay
# Processing Record 37 of Set 14 | narasannapeta
# Processing Record 38 of Set 14 | vanimo
# Processing Record 39 of Set 14 | ostrovnoy
# Processing Record 40 of Set 14 | mindelo
# Processing Record 41 of Set 14 | palmer
# Processing Record 42 of Set 14 | sevierville
# Processing Record 43 of Set 14 | north bend
# Processing Record 44 of Set 14 | paamiut
# Processing Record 45 of Set 14 | altamira
# Processing Record 46 of Set 14 | amarante do maranhao
# Processing Record 47 of Set 14 | belle fourche
# Processing Record 48 of Set 14 | klyuchevskiy
# Processing Record 49 of Set 14 | ciro marina
# Processing Record 50 of Set 14 | olinda
# Processing Record 1 of Set 15 | aktash
# Processing Record 2 of Set 15 | bage
# Processing Record 3 of Set 15 | buchanan
# Processing Record 4 of Set 15 | yuzhno-yeniseyskiy
# Missing data or missing city...skipping city
# Processing Record 5 of Set 15 | krutikha
# Processing Record 6 of Set 15 | semenyih
# Processing Record 7 of Set 15 | shinjo
# Processing Record 8 of Set 15 | tenkodogo
# Processing Record 9 of Set 15 | aksha
# Processing Record 10 of Set 15 | pangody
# Processing Record 11 of Set 15 | la palma
# Processing Record 12 of Set 15 | luganville
# Processing Record 13 of Set 15 | puerto pinasco
# Missing data or missing city...skipping city
# Processing Record 14 of Set 15 | malangali
# Processing Record 15 of Set 15 | bumba
# Processing Record 16 of Set 15 | nykoping
# Processing Record 17 of Set 15 | lipari
# Processing Record 18 of Set 15 | balaipungut
# Processing Record 19 of Set 15 | mokhsogollokh
# Processing Record 20 of Set 15 | mbulu
# Processing Record 21 of Set 15 | sanchor
# Processing Record 22 of Set 15 | ngunguru
# Processing Record 23 of Set 15 | dwarka
# Processing Record 24 of Set 15 | bonthe
# Processing Record 25 of Set 15 | shumikha
# Processing Record 26 of Set 15 | chagda
# Missing data or missing city...skipping city
# Processing Record 27 of Set 15 | port-gentil
# Processing Record 28 of Set 15 | barbar
# Missing data or missing city...skipping city
# Processing Record 29 of Set 15 | campbell river
# Processing Record 30 of Set 15 | lethem
# Processing Record 31 of Set 15 | itarema
# Processing Record 32 of Set 15 | maloshuyka
# Missing data or missing city...skipping city
# Processing Record 33 of Set 15 | keti bandar
# Processing Record 34 of Set 15 | waterloo
# Processing Record 35 of Set 15 | narok
# Processing Record 36 of Set 15 | maragogi
# Processing Record 37 of Set 15 | namatanai
# Processing Record 38 of Set 15 | kilindoni
# Processing Record 39 of Set 15 | elk city
# Processing Record 40 of Set 15 | saint anthony
# Processing Record 41 of Set 15 | bom conselho
# Processing Record 42 of Set 15 | gorontalo
# Processing Record 43 of Set 15 | lumphat
# Processing Record 44 of Set 15 | haridwar
# Processing Record 45 of Set 15 | lima
# Processing Record 46 of Set 15 | aranos
# Processing Record 47 of Set 15 | chaumont
# Processing Record 48 of Set 15 | kirkwall
# Processing Record 49 of Set 15 | diego de almagro
# Processing Record 50 of Set 15 | vysokogornyy
# Processing Record 1 of Set 16 | penzance
# Processing Record 2 of Set 16 | nokaneng
# Processing Record 3 of Set 16 | peniche
# Processing Record 4 of Set 16 | srandakan
# Processing Record 5 of Set 16 | falconara marittima
# Processing Record 6 of Set 16 | half moon bay
# Processing Record 7 of Set 16 | podor
# Processing Record 8 of Set 16 | pushkar
# Processing Record 9 of Set 16 | bonavista
# --------------------
# Data pull complete. 71 cities were skipped.
# --------------------

# %%
len(city_api_data)
# Out:
# 688

# %%
city_data_df = pd.DataFrame(city_api_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  % Humidity  % Cloudiness  \
# 0  Hambantota      LK   6.1241   81.1185     78.49          84            70
# 1    Lingyuan      CN  41.2400  119.4011     43.57          73           100
# 2      Hasaki      JP  35.7333  140.8333     52.20          60            99
# 3      Albany      US  42.6001  -73.9662     58.68          91           100
# 4   Carnarvon      AU -24.8667  113.6333     66.27          68             0
#
#    Wind Speed Weather Desciption
# 0        1.50      broken clouds
# 1       10.51    overcast clouds
# 2        6.26    overcast clouds
# 3        4.00    overcast clouds
# 4       16.11          clear sky

# %%
# Create the output file (CSV).
output_data_file = "./WeatherPy_Database.csv"
# Export the City_Data into a CSV.sdfsdf
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
base_url = "Http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+weather_api_key
new_url = f"{base_url}&q=minneapolis"
data = requests.get(new_url).json()
data['sys']['country']
# Out:
# 'US'

# %%
# Dependencies and Setup
import requests
import gmaps
import json
# Import API key
from config import g_key

# %%
base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
parameters = {'radius':'5000',
              'key':g_key,
              'type':'lodging',
              'location': '48.8566, 2.3522'}

data = requests.get(base_url, params=parameters).json()
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEDOTEwnRLNPvPLJUhyTPgP1PGIlICy8_oMULrpaEgWmQNNJWqOXBpKPiiXwJNx3aWOpzX68bSluHvY5wDP2vLhIw0q6KnKcqcHhmi9MKaoXZ-K_mRp2FPO1NJrja0XJ-4XSZ200tujFQOY4RBbaElUXLzQZPcyVJO5nJsFR-4u4cWfr1Yqclp4DAka1Qrv1XuIUS5naiQ6nzZWWBjyCuLhBqoPZeszFFxP51sMDNY1_EpN9gH-6U84ig9Tu6s1Ixbvuo9PWQZq2aOpkWIKh71eO_xjNxMyd6RuitqAmy6S8u0PGo76xwiTjGwQCeQ-WYgo1EViQw8zj1xkAXAyLPT0qzk4q-LMMQhgQGnmgMx4HcUhX7tagZk9wU3k6yydXHgjdh526hFEyfwYZi_cIPcSMrUHrMgk82stIyoBk-Do5ODfW60lWgxl6',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'Aap_uEDJOryRqerEyGIBSzrQ2zIalabmsBjBIdLHzV2RDD5P3P_H2unYxagAvF_cE537MtVPAjCyp0LcArt5gbZPeo6eeh17h2-Y0lGWX3Xex5Sq2QxfrZc0z2DSGdPJEQ2kvlqFlk2vBT-CvQ820wM-Nev0Z8hLeRZaZBWqP-2O_Mvu1V-m',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 302,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.85954748029151,
#       'lng': 2.347782830291502},
#      'southwest': {'lat': 48.85684951970851, 'lng': 2.345084869708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Britannique - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1426,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'],
#      'photo_reference': 'Aap_uEBw3YvrA7Jol8MNkDygawow4pBgiNg2pN9BwTvwgedHYIa6MbhBf7fYilHAI1D9lsbQSVi7ksp3Km32f1umbUVdTJyc1UyHedXT8TOMA5tclgdc8LHE-7v7uuMnxE7D8rWNxiKLrc1tIRbEEEma7O1dMPRaN_Dt9X5ycKuFa_TBW37C',
#      'width': 1476}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.6,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 626,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.8617653302915,
#       'lng': 2.348020880291502},
#      'southwest': {'lat': 48.85906736970851, 'lng': 2.345322919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Les Halles Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 849,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart hotel Paris)</a>'],
#      'photo_reference': 'Aap_uEBzMkoVQmzdvfphCabWK1Xe-AsfVqB4LZhCYicUeGFqRbBdqbHd9uQ4jUMCMPslINpH97_LzTja5qY7GncOA4QfH4JmMv1FY25wS7oqNY-NKkS6cnkUMfY8E2nB00IvRiWKhc_QCEHmkrbqkPpMvJHr33rbMZYuw2PUpBbTEzmtBp1o',
#      'width': 1280}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 861,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607658, 'lng': 2.3465318},
#     'viewport': {'northeast': {'lat': 48.8620584302915,
#       'lng': 2.347692880291501},
#      'southwest': {'lat': 48.85936046970851, 'lng': 2.344994919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Novotel Paris Les Halles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel Paris Les Halles</a>'],
#      'photo_reference': 'Aap_uEDovYAGaQgYYfSGIN92atM_B1ujtaN4WLFzvGCD5C7eIO01P3oN1MT4EesayjW-yUl28kimRuTkRJE2hiHuTnZ8waSQkZA6OgkD-PEwFfVemADw-a4KrOFqmpmNvhgxhQDM8PCUM_csKa2x2mp13fGlvGFh0YpwDbkM9QuQLFL7OJyL',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8J Paris, France',
#     'global_code': '8FW4V86W+8J'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2246,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.860352, 'lng': 2.3440948},
#     'viewport': {'northeast': {'lat': 48.86165553029149,
#       'lng': 2.345549080291502},
#      'southwest': {'lat': 48.8589575697085, 'lng': 2.342851119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'Aap_uECKxjqCO9wRhSwA53JJsRSVQK0mQHvReflxnLOxVyuyLMGDQUmvwyt0agWrewR3vZFusR2TAQ6L4iWu9XBgWXZVTjbPCjaL9g2jOqnptB7MTJXMMKnLOLrFFiwfLG2w6DazhgHmnPS6fEhEAHit_Du9PFuZO3trtK5QHnNASHs28Dkg',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 279,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Citadines Saint-Germain-des-Prés Paris (Apart hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris</a>'],
#      'photo_reference': 'Aap_uEBRD6XMXQIJL5FaEpD9ZqKrlS2DucAbp2TVVQ5l9v_8RIi6p0OfbbQmDsVxVMar7lzFxKhqkVZ6xKFTEg3ybagV2MjOoK3P4dZVLmPbmZFJOh-t3vpOzi4dHqHw3DskX8xqo3g4x1IImQ_IC7Qdt-dfU2HRRd7nGRvsDDeacXhzlcQ1',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 707,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8663519, 'lng': 2.3606461},
#     'viewport': {'northeast': {'lat': 48.86775308029149,
#       'lng': 2.361905130291502},
#      'southwest': {'lat': 48.8650551197085, 'lng': 2.359207169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Paris France Hôtel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2673,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102332962500946068613">Paris France Hôtel</a>'],
#      'photo_reference': 'Aap_uECYp0SD-ARD-7ZjhoKkBCRXeWEeZLhWz6m9disek-IoASHob1gLpGMXwBJvRDYQusP3HuzOWagsKdNdbYQM1viCKI-yYNEV9qu5Q97pP80Be0Zn3qHgI_6VFhApBXHixQqgHtqpI42xTShqRz_eyQ_WDYn87YLwY_VGpPcBGsuusFB1',
#      'width': 3463}],
#    'place_id': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'plus_code': {'compound_code': 'V986+G7 Paris, France',
#     'global_code': '8FW4V986+G7'},
#    'rating': 4.3,
#    'reference': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 387,
#    'vicinity': '72 Rue de Turbigo, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86386539999999, 'lng': 2.3325488},
#     'viewport': {'northeast': {'lat': 48.8650759802915,
#       'lng': 2.333775730291502},
#      'southwest': {'lat': 48.8623780197085, 'lng': 2.331077769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Regina Louvre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109908333790946649027">Hôtel Regina Louvre</a>'],
#      'photo_reference': 'Aap_uEDxIQF0iogb4xiGpU64VaTznQCtVEUMqSq42ORubWLi5c03-pvqW9iXKRD6wPTPlcsQBnBWWB_vPleC_10tnTJiXj5m0P7VvqmrMhDyzUoFmYym9-b7K5H9mfyDl2YFVW6bFOjCsAYW0lFoc6gxuiBFi-CAQmzL4luEGeI-xu21sRhX',
#      'width': 5550}],
#    'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#     'global_code': '8FW4V87M+G2'},
#    'rating': 4.4,
#    'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 507,
#    'vicinity': '2 Place des Pyramides, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84795229999999, 'lng': 2.370869},
#     'viewport': {'northeast': {'lat': 48.8492035302915,
#       'lng': 2.372290080291501},
#      'southwest': {'lat': 48.8465055697085, 'lng': 2.369592119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101181280085797863615">Kevin Nguyen</a>'],
#      'photo_reference': 'Aap_uEAZjoZR76MEQhh9MLBX-PIAeATcWUk-_KqVWOqlRJDvEAy-G5iCCZjba7Wcf89sEmlByrdydLWl-bbjjYPRS7gOcGnagd2hjqRbPVwR5KMHoVxURfsZQwzwcygkO-_FhPXELfb0fyBqmqvdAIw-0LPVoKh5fO3FYsGKi6D7bUrnZ2wL',
#      'width': 1536}],
#    'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#     'global_code': '8FW4R9XC+58'},
#    'rating': 4.1,
#    'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 836,
#    'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#     'viewport': {'northeast': {'lat': 48.87241888029151,
#       'lng': 2.351188530291502},
#      'southwest': {'lat': 48.86972091970851, 'lng': 2.348490569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel des Comédies Paris',
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114696623290303183213">Noble</a>'],
#      'photo_reference': 'Aap_uEDoyIfZK3yYGq_yGbmFhHbb7CuI3V7dUGE4MdQEj5tV4rNi-4_fo7Gdmv4qmHyJGsAqQkhRjB8ffil8VxdNYG6neTpCdDtSA3cpk5_X4ea7x1bPqL8HQPltJKZEn8OnvTSMf_iFZTJvprtWNp08OR31l_nBQt19dOCngJQWxradYVN4',
#      'width': 3000}],
#    'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#     'global_code': '8FW4V8CX+CX'},
#    'rating': 4.2,
#    'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 195,
#    'vicinity': "8 Rue d'Hauteville, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84754640000001, 'lng': 2.3718722},
#     'viewport': {'northeast': {'lat': 48.8488750302915,
#       'lng': 2.373125480291502},
#      'southwest': {'lat': 48.8461770697085, 'lng': 2.370427519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel De France Gare de Lyon Bastille',
#    'photos': [{'height': 787,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117462031751048846575">Hôtel De France Gare de Lyon Bastille</a>'],
#      'photo_reference': 'Aap_uEDc-PO7JItMGtHbwlpGWP73KB3054u-OfW-5JDBovlPYJqlU70sQPnIHo5ATaklaJlJyLKuUZSjtWa88Pe-dkuQUqSObnfjByDWa2Jy44Oz4sPwPvoRZfUvPXquQzkzn_hGpnrJ6FB5M4V0p2YKuoYYh_w5Ws5L_7PUUAkJsLuA-FHX',
#      'width': 1181}],
#    'place_id': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'plus_code': {'compound_code': 'R9XC+2P Paris, France',
#     'global_code': '8FW4R9XC+2P'},
#    'rating': 3.3,
#    'reference': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 381,
#    'vicinity': '12 Rue de Lyon, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8717386, 'lng': 2.3447052},
#     'viewport': {'northeast': {'lat': 48.8731374802915,
#       'lng': 2.346059980291502},
#      'southwest': {'lat': 48.8704395197085, 'lng': 2.343362019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Prélude Opéra Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5120,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113098608949799179620">Chrystelle Baudry</a>'],
#      'photo_reference': 'Aap_uEAW8cCV6bbU5zddw9ULD809_WIbm134m2z1C_kIjDCxxLIr637xDqotpaHRblbKI9SI_A8hpu5ZyEpkxZVg4oDX7rGaKGwwafIMuQipVoWDYAJsb3_NFjKz7-Yhpy6flqoQUMvjIXkUE62xwhyh-J01fFYSrpMd-4LC2RVJN-sh1mUJ',
#      'width': 3840}],
#    'place_id': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'plus_code': {'compound_code': 'V8CV+MV Paris, France',
#     'global_code': '8FW4V8CV+MV'},
#    'rating': 4.2,
#    'reference': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 375,
#    'vicinity': '8 Cité Bergère, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8423491, 'lng': 2.3632246},
#     'viewport': {'northeast': {'lat': 48.8436624802915,
#       'lng': 2.364708880291502},
#      'southwest': {'lat': 48.8409645197085, 'lng': 2.362010919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Libertel Austerlitz Jardin des Plantes',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114802271282641766772">Hôtel Libertel Austerlitz Jardin des Plantes</a>'],
#      'photo_reference': 'Aap_uEBQrJfKcyvHNEF9WNtqhUn6unBIdORxTjcsb7gRkiRLBHAYAN1zSAk7eOZmO0Lfsp7ZVkIIY6MZZFiM4fRohiY1OnFsZ6Xwsk0xtCGge0rCG4R5_nNPiPmsjzIXT_-8U3lJu1CzjTe0wFYvOCX2V4ZtPYoLmsTQLBv1TNYorsqFiV4y',
#      'width': 6720}],
#    'place_id': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'plus_code': {'compound_code': 'R9R7+W7 Paris, France',
#     'global_code': '8FW4R9R7+W7'},
#    'rating': 4,
#    'reference': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 441,
#    'vicinity': "12 Boulevard de l'Hôpital, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8642974, 'lng': 2.3308142},
#     'viewport': {'northeast': {'lat': 48.8655789302915,
#       'lng': 2.332153980291502},
#      'southwest': {'lat': 48.8628809697085, 'lng': 2.329456019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Saint James Albany Paris Hôtel Spa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108570400659068256718">Saint James Albany Paris Hôtel Spa</a>'],
#      'photo_reference': 'Aap_uEDFT4etky7C9j1M4EfKQqb0WCQc0Flndk-UvEKqo_dNqUz0_FuDSqPVm_-bTcgQ9uFCOU3YGD7ACD25MXXFn5rx8Yi6i2VZe_UzZY1U3ZtAeMrRb_k1Vvop4mTQQfgI1cdgtA29Ctg5x-UCl8keDUToku7M4BigoZHZ4zl1H3Nre3DF',
#      'width': 600}],
#    'place_id': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'plus_code': {'compound_code': 'V87J+P8 Paris, France',
#     'global_code': '8FW4V87J+P8'},
#    'rating': 4,
#    'reference': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1075,
#    'vicinity': '202 Rue de Rivoli, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.87110329999999, 'lng': 2.3389728},
#     'viewport': {'northeast': {'lat': 48.8724588802915,
#       'lng': 2.340112930291502},
#      'southwest': {'lat': 48.8697609197085, 'lng': 2.337414969708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Icône',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1066,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108137830440312077288">Hôtel Icône</a>'],
#      'photo_reference': 'Aap_uED1dE40XE5UcOcL-ZQlhvr8f8cEhsL898yqk_kJb4bhQTo8_FSM003iR-gTMw3LnltmNApae6C7DJwWZnjWMymFq9RRrhLAXntaiJmKSkd6Wi-8zPlcxFFSmw-HCsnWqjJ9veg9R8h7tK9nh0cbP7YaQnEGCNWdRmFZuo_vet5ddWAN',
#      'width': 1600}],
#    'place_id': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'plus_code': {'compound_code': 'V8CQ+CH Paris, France',
#     'global_code': '8FW4V8CQ+CH'},
#    'rating': 3.7,
#    'reference': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 141,
#    'vicinity': "4 Rue d'Amboise, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.8538838802915,
#       'lng': 2.348601530291502},
#      'southwest': {'lat': 48.8511859197085, 'lng': 2.345903569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114852001362047630790">Georgia Hentze</a>'],
#      'photo_reference': 'Aap_uEDnB0hgkwkFw9brgPEnbWv-E0kDoUsit3t5jiPClPb3qHHXuz6h1SHCNQmPPEDzM0qx_StF3Q1rTg-2lWTSyTlGodb6bFTEYJBskw6XGJmGXPv2mFaPwf7MUyPVQ8z8uYQhNoWRWaG0hguZvK2YSqOcA6nvgqyIubgjkjs9TNLJaIAr',
#      'width': 3024}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 147,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544403302915,
#       'lng': 2.346001280291502},
#      'southwest': {'lat': 48.8517423697085, 'lng': 2.343303319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'Aap_uECj7_9jdOm5UTPAi8u0dqtoz0ITHQnZhmmV5yC1PMQLjyRBGYIRAdSJTS-Cb1aqR_bfd8z27LHcexrCsNFg9KcBvh4WETy4l9uZE7AODPiazoq_oJQjAqGX8q6nZSbME173pxXZXXjomIJbF5J7wBfP0uiEu_EvMu3P19OI7dcBnnu9',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 332,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499443, 'lng': 2.3462474},
#     'viewport': {'northeast': {'lat': 48.8512737302915,
#       'lng': 2.347507380291502},
#      'southwest': {'lat': 48.8485757697085, 'lng': 2.344809419708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Home Latin',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108547915404801536469">Jp Homma</a>'],
#      'photo_reference': 'Aap_uEB7SbCyOWtxEIpnWOXN59F-J2jTbBBxwFZmHIkHWPEZ_dBqm2zy39noT6wKfAbJ2b2AMUqzhazwUxpy_0BZXcIkWiE91CDJ9oUHlcNAWVGnVrwIRTzuWuoTaw5W_Ja9SU52Oosfe6Lf7oYCGKfJ7g3_uztQiCThUWUwTAbckjJhmu9s',
#      'width': 4608}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.5,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 286,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85473870000001, 'lng': 2.3395455},
#     'viewport': {'northeast': {'lat': 48.8561127802915,
#       'lng': 2.340820530291502},
#      'southwest': {'lat': 48.8534148197085, 'lng': 2.338122569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hôtel d'Aubusson",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2174,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel d&#39;Aubusson Paris</a>'],
#      'photo_reference': 'Aap_uEAJytHJ7sqh00cHUKve-ANncpBF-FmPHZOwT9jI5j6BWO1nmby7FR6g2eTEhKpTZldSswjp-8C3b6zr-mE3Y6CGo6HTi_mvxbpuELGIyss5lULoFyzYb4nO73zUJcVPhHKgxb6sXC4T17I1_65Vx4Vf-P-oVxy6gopVIA82Ac_z5q9_',
#      'width': 1739}],
#    'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#     'global_code': '8FW4V83Q+VR'},
#    'rating': 4.7,
#    'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 293,
#    'vicinity': '33 Rue Dauphine, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.8531470802915,
#       'lng': 2.346121880291502},
#      'southwest': {'lat': 48.8504491197085, 'lng': 2.343423919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'Aap_uECvB3LXsQntnNEsUWkleWaXCJ9yYycR4PjrLCUun9oJtlJbVGN5fQzoladKTIgar4Eyc9EIp5a8iluuZFS8okHgI5Gyr8uT6K8uvvRu0mGVCh9uWDBGPY25wFPtCHlU7ux4alfcOvf5_RdAscUeB4_8XGjQ_woYkLaYpttiQAGDtWb2',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 140,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %%
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "Aap_uEDOTEwnRLNPvPLJUhyTPgP1PGIlICy8_oMULrpaEgWmQNNJWqOXBpKPiiXwJNx3aWOpzX68bSluHvY5wDP2vLhIw0q6KnKcqcHhmi9MKaoXZ-K_mRp2FPO1NJrja0XJ-4XSZ200tujFQOY4RBbaElUXLzQZPcyVJO5nJsFR-4u4cWfr1Yqclp4DAka1Qrv1XuIUS5naiQ6nzZWWBjyCuLhBqoPZeszFFxP51sMDNY1_EpN9gH-6U84ig9Tu6s1Ixbvuo9PWQZq2aOpkWIKh71eO_xjNxMyd6RuitqAmy6S8u0PGo76xwiTjGwQCeQ-WYgo1EViQw8zj1xkAXAyLPT0qzk4q-LMMQhgQGnmgMx4HcUhX7tagZk9wU3k6yydXHgjdh526hFEyfwYZi_cIPcSMrUHrMgk82stIyoBk-Do5ODfW60lWgxl6",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8581126,
#                     "lng": 2.3529277
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8594360302915,
#                         "lng": 2.354355480291502
#                     },
#                     "southwest": {
#                         "lat": 48.8567380697085,
#                         "lng": 2.351657519708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Duo",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107554201425443337224\">H\u00f4tel Duo</a>"
#                     ],
#                     "photo_reference": "Aap_uEDJOryRqerEyGIBSzrQ2zIalabmsBjBIdLHzV2RDD5P3P_H2unYxagAvF_cE537MtVPAjCyp0LcArt5gbZPeo6eeh17h2-Y0lGWX3Xex5Sq2QxfrZc0z2DSGdPJEQ2kvlqFlk2vBT-CvQ820wM-Nev0Z8hLeRZaZBWqP-2O_Mvu1V-m",
#                     "width": 5760
#                 }
#             ],
#             "place_id": "ChIJWU9CqB1u5kcR5P1F2SMoJmc",
#             "plus_code": {
#                 "compound_code": "V953+65 Paris, France",
#                 "global_code": "8FW4V953+65"
#             },
#             "rating": 4.2,
#             "reference": "ChIJWU9CqB1u5kcR5P1F2SMoJmc",
#             "scope": "GOOGLE",
#             "types": [
#                 "night_club",
#                 "spa",
#                 "lodging",
#                 "bar",
#                 "gym",
#                 "health",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 302,
#             "vicinity": "11 Rue du Temple, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8582861,
#                     "lng": 2.3464944
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.85954748029151,
#                         "lng": 2.347782830291502
#                     },
#                     "southwest": {
#                         "lat": 48.85684951970851,
#                         "lng": 2.345084869708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Britannique - Paris Centre",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1426,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108984000175492464929\">H\u00f4tel Britannique - Paris Centre</a>"
#                     ],
#                     "photo_reference": "Aap_uEBw3YvrA7Jol8MNkDygawow4pBgiNg2pN9BwTvwgedHYIa6MbhBf7fYilHAI1D9lsbQSVi7ksp3Km32f1umbUVdTJyc1UyHedXT8TOMA5tclgdc8LHE-7v7uuMnxE7D8rWNxiKLrc1tIRbEEEma7O1dMPRaN_Dt9X5ycKuFa_TBW37C",
#                     "width": 1476
#                 }
#             ],
#             "place_id": "ChIJ-4Siox9u5kcRm9vM6DcMXyU",
#             "plus_code": {
#                 "compound_code": "V85W+8H Paris, France",
#                 "global_code": "8FW4V85W+8H"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ-4Siox9u5kcRm9vM6DcMXyU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 626,
#             "vicinity": "20 Avenue Victoria, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8606655,
#                     "lng": 2.3469293
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8617653302915,
#                         "lng": 2.348020880291502
#                     },
#                     "southwest": {
#                         "lat": 48.85906736970851,
#                         "lng": 2.345322919708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Citadines Les Halles Paris",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 849,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102565262508115704337\">Citadines Les Halles Paris (Apart hotel Paris)</a>"
#                     ],
#                     "photo_reference": "Aap_uEBzMkoVQmzdvfphCabWK1Xe-AsfVqB4LZhCYicUeGFqRbBdqbHd9uQ4jUMCMPslINpH97_LzTja5qY7GncOA4QfH4JmMv1FY25wS7oqNY-NKkS6cnkUMfY8E2nB00IvRiWKhc_QCEHmkrbqkPpMvJHr33rbMZYuw2PUpBbTEzmtBp1o",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJQ_QDrxhu5kcRJzNxLLEOSfU",
#             "plus_code": {
#                 "compound_code": "V86W+7Q Paris, France",
#                 "global_code": "8FW4V86W+7Q"
#             },
#             "rating": 4.1,
#             "reference": "ChIJQ_QDrxhu5kcRJzNxLLEOSfU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 861,
#             "vicinity": "4 Rue des Innocents, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8607658,
#                     "lng": 2.3465318
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8620584302915,
#                         "lng": 2.347692880291501
#                     },
#                     "southwest": {
#                         "lat": 48.85936046970851,
#                         "lng": 2.344994919708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Novotel Paris Les Halles",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111815616573299411056\">Novotel Paris Les Halles</a>"
#                     ],
#                     "photo_reference": "Aap_uEDovYAGaQgYYfSGIN92atM_B1ujtaN4WLFzvGCD5C7eIO01P3oN1MT4EesayjW-yUl28kimRuTkRJE2hiHuTnZ8waSQkZA6OgkD-PEwFfVemADw-a4KrOFqmpmNvhgxhQDM8PCUM_csKa2x2mp13fGlvGFh0YpwDbkM9QuQLFL7OJyL",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJGW2pNx9u5kcRI3oyL8NG5BQ",
#             "plus_code": {
#                 "compound_code": "V86W+8J Paris, France",
#                 "global_code": "8FW4V86W+8J"
#             },
#             "rating": 4.4,
#             "reference": "ChIJGW2pNx9u5kcRI3oyL8NG5BQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2246,
#             "vicinity": "8 Place Marguerite de Navarre, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.860352,
#                     "lng": 2.3440948
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.86165553029149,
#                         "lng": 2.345549080291502
#                     },
#                     "southwest": {
#                         "lat": 48.8589575697085,
#                         "lng": 2.342851119708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Ducs de Bourgogne",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1390,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101411638353598558320\">H\u00f4tel Ducs de Bourgogne</a>"
#                     ],
#                     "photo_reference": "Aap_uECKxjqCO9wRhSwA53JJsRSVQK0mQHvReflxnLOxVyuyLMGDQUmvwyt0agWrewR3vZFusR2TAQ6L4iWu9XBgWXZVTjbPCjaL9g2jOqnptB7MTJXMMKnLOLrFFiwfLG2w6DazhgHmnPS6fEhEAHit_Du9PFuZO3trtK5QHnNASHs28Dkg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJifTG5yFu5kcRdnisbwxnAx4",
#             "plus_code": {
#                 "compound_code": "V86V+4J Paris, France",
#                 "global_code": "8FW4V86V+4J"
#             },
#             "rating": 4.5,
#             "reference": "ChIJifTG5yFu5kcRdnisbwxnAx4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 279,
#             "vicinity": "19 Rue du Pont Neuf, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8555091,
#                     "lng": 2.3408736
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8569076302915,
#                         "lng": 2.342319280291502
#                     },
#                     "southwest": {
#                         "lat": 48.8542096697085,
#                         "lng": 2.339621319708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Citadines Saint-Germain-des-Pr\u00e9s Paris (Apart hotel Paris)",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113188832595116816387\">Citadines Saint-Germain-des-Pr\u00e9s Paris</a>"
#                     ],
#                     "photo_reference": "Aap_uEBRD6XMXQIJL5FaEpD9ZqKrlS2DucAbp2TVVQ5l9v_8RIi6p0OfbbQmDsVxVMar7lzFxKhqkVZ6xKFTEg3ybagV2MjOoK3P4dZVLmPbmZFJOh-t3vpOzi4dHqHw3DskX8xqo3g4x1IImQ_IC7Qdt-dfU2HRRd7nGRvsDDeacXhzlcQ1",
#                     "width": 6720
#                 }
#             ],
#             "place_id": "ChIJo5pYcN9x5kcRERXdocMgqmE",
#             "plus_code": {
#                 "compound_code": "V84R+68 Paris, France",
#                 "global_code": "8FW4V84R+68"
#             },
#             "rating": 4.3,
#             "reference": "ChIJo5pYcN9x5kcRERXdocMgqmE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 707,
#             "vicinity": "53 ter Quai des Grands Augustins, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8663519,
#                     "lng": 2.3606461
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.86775308029149,
#                         "lng": 2.361905130291502
#                     },
#                     "southwest": {
#                         "lat": 48.8650551197085,
#                         "lng": 2.359207169708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Paris France H\u00f4tel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2673,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102332962500946068613\">Paris France H\u00f4tel</a>"
#                     ],
#                     "photo_reference": "Aap_uECYp0SD-ARD-7ZjhoKkBCRXeWEeZLhWz6m9disek-IoASHob1gLpGMXwBJvRDYQusP3HuzOWagsKdNdbYQM1viCKI-yYNEV9qu5Q97pP80Be0Zn3qHgI_6VFhApBXHixQqgHtqpI42xTShqRz_eyQ_WDYn87YLwY_VGpPcBGsuusFB1",
#                     "width": 3463
#                 }
#             ],
#             "place_id": "ChIJhXWLZg9u5kcRDVyqoZYgcmg",
#             "plus_code": {
#                 "compound_code": "V986+G7 Paris, France",
#                 "global_code": "8FW4V986+G7"
#             },
#             "rating": 4.3,
#             "reference": "ChIJhXWLZg9u5kcRDVyqoZYgcmg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 387,
#             "vicinity": "72 Rue de Turbigo, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.86386539999999,
#                     "lng": 2.3325488
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8650759802915,
#                         "lng": 2.333775730291502
#                     },
#                     "southwest": {
#                         "lat": 48.8623780197085,
#                         "lng": 2.331077769708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Hotel Regina Louvre",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3700,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109908333790946649027\">H\u00f4tel Regina Louvre</a>"
#                     ],
#                     "photo_reference": "Aap_uEDxIQF0iogb4xiGpU64VaTznQCtVEUMqSq42ORubWLi5c03-pvqW9iXKRD6wPTPlcsQBnBWWB_vPleC_10tnTJiXj5m0P7VvqmrMhDyzUoFmYym9-b7K5H9mfyDl2YFVW6bFOjCsAYW0lFoc6gxuiBFi-CAQmzL4luEGeI-xu21sRhX",
#                     "width": 5550
#                 }
#             ],
#             "place_id": "ChIJP_-HCS9u5kcRsj9b1x7Pl8w",
#             "plus_code": {
#                 "compound_code": "V87M+G2 Paris, France",
#                 "global_code": "8FW4V87M+G2"
#             },
#             "rating": 4.4,
#             "reference": "ChIJP_-HCS9u5kcRsj9b1x7Pl8w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 507,
#             "vicinity": "2 Place des Pyramides, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.84795229999999,
#                     "lng": 2.370869
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8492035302915,
#                         "lng": 2.372290080291501
#                     },
#                     "southwest": {
#                         "lat": 48.8465055697085,
#                         "lng": 2.369592119708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "ibis Paris Gare de Lyon Ledru Rollin 12\u00e8me",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2048,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101181280085797863615\">Kevin Nguyen</a>"
#                     ],
#                     "photo_reference": "Aap_uEAZjoZR76MEQhh9MLBX-PIAeATcWUk-_KqVWOqlRJDvEAy-G5iCCZjba7Wcf89sEmlByrdydLWl-bbjjYPRS7gOcGnagd2hjqRbPVwR5KMHoVxURfsZQwzwcygkO-_FhPXELfb0fyBqmqvdAIw-0LPVoKh5fO3FYsGKi6D7bUrnZ2wL",
#                     "width": 1536
#                 }
#             ],
#             "place_id": "ChIJ9RNxcQNy5kcRnZJ4vsuXcow",
#             "plus_code": {
#                 "compound_code": "R9XC+58 Paris, France",
#                 "global_code": "8FW4R9XC+58"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ9RNxcQNy5kcRnZJ4vsuXcow",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 836,
#             "vicinity": "41/43 Avenue Ledru Rollin, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8710647,
#                     "lng": 2.34991
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.87241888029151,
#                         "lng": 2.351188530291502
#                     },
#                     "southwest": {
#                         "lat": 48.86972091970851,
#                         "lng": 2.348490569708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel des Com\u00e9dies Paris",
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114696623290303183213\">Noble</a>"
#                     ],
#                     "photo_reference": "Aap_uEDoyIfZK3yYGq_yGbmFhHbb7CuI3V7dUGE4MdQEj5tV4rNi-4_fo7Gdmv4qmHyJGsAqQkhRjB8ffil8VxdNYG6neTpCdDtSA3cpk5_X4ea7x1bPqL8HQPltJKZEn8OnvTSMf_iFZTJvprtWNp08OR31l_nBQt19dOCngJQWxradYVN4",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJn6ginxZu5kcRmAEK0OHm0cI",
#             "plus_code": {
#                 "compound_code": "V8CX+CX Paris, France",
#                 "global_code": "8FW4V8CX+CX"
#             },
#             "rating": 4.2,
#             "reference": "ChIJn6ginxZu5kcRmAEK0OHm0cI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 195,
#             "vicinity": "8 Rue d'Hauteville, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.84754640000001,
#                     "lng": 2.3718722
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8488750302915,
#                         "lng": 2.373125480291502
#                     },
#                     "southwest": {
#                         "lat": 48.8461770697085,
#                         "lng": 2.370427519708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel De France Gare de Lyon Bastille",
#             "photos": [
#                 {
#                     "height": 787,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117462031751048846575\">H\u00f4tel De France Gare de Lyon Bastille</a>"
#                     ],
#                     "photo_reference": "Aap_uEDc-PO7JItMGtHbwlpGWP73KB3054u-OfW-5JDBovlPYJqlU70sQPnIHo5ATaklaJlJyLKuUZSjtWa88Pe-dkuQUqSObnfjByDWa2Jy44Oz4sPwPvoRZfUvPXquQzkzn_hGpnrJ6FB5M4V0p2YKuoYYh_w5Ws5L_7PUUAkJsLuA-FHX",
#                     "width": 1181
#                 }
#             ],
#             "place_id": "ChIJz6DBYgNy5kcRhOu1LhDIECM",
#             "plus_code": {
#                 "compound_code": "R9XC+2P Paris, France",
#                 "global_code": "8FW4R9XC+2P"
#             },
#             "rating": 3.3,
#             "reference": "ChIJz6DBYgNy5kcRhOu1LhDIECM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 381,
#             "vicinity": "12 Rue de Lyon, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8717386,
#                     "lng": 2.3447052
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8731374802915,
#                         "lng": 2.346059980291502
#                     },
#                     "southwest": {
#                         "lat": 48.8704395197085,
#                         "lng": 2.343362019708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Pr\u00e9lude Op\u00e9ra Paris",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 5120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113098608949799179620\">Chrystelle Baudry</a>"
#                     ],
#                     "photo_reference": "Aap_uEAW8cCV6bbU5zddw9ULD809_WIbm134m2z1C_kIjDCxxLIr637xDqotpaHRblbKI9SI_A8hpu5ZyEpkxZVg4oDX7rGaKGwwafIMuQipVoWDYAJsb3_NFjKz7-Yhpy6flqoQUMvjIXkUE62xwhyh-J01fFYSrpMd-4LC2RVJN-sh1mUJ",
#                     "width": 3840
#                 }
#             ],
#             "place_id": "ChIJ8e3Qcj5u5kcR2MIGwNxustk",
#             "plus_code": {
#                 "compound_code": "V8CV+MV Paris, France",
#                 "global_code": "8FW4V8CV+MV"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ8e3Qcj5u5kcR2MIGwNxustk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 375,
#             "vicinity": "8 Cit\u00e9 Berg\u00e8re, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8423491,
#                     "lng": 2.3632246
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8436624802915,
#                         "lng": 2.364708880291502
#                     },
#                     "southwest": {
#                         "lat": 48.8409645197085,
#                         "lng": 2.362010919708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Libertel Austerlitz Jardin des Plantes",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4480,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114802271282641766772\">H\u00f4tel Libertel Austerlitz Jardin des Plantes</a>"
#                     ],
#                     "photo_reference": "Aap_uEBQrJfKcyvHNEF9WNtqhUn6unBIdORxTjcsb7gRkiRLBHAYAN1zSAk7eOZmO0Lfsp7ZVkIIY6MZZFiM4fRohiY1OnFsZ6Xwsk0xtCGge0rCG4R5_nNPiPmsjzIXT_-8U3lJu1CzjTe0wFYvOCX2V4ZtPYoLmsTQLBv1TNYorsqFiV4y",
#                     "width": 6720
#                 }
#             ],
#             "place_id": "ChIJe-udXPZx5kcRKURHNFv5BSw",
#             "plus_code": {
#                 "compound_code": "R9R7+W7 Paris, France",
#                 "global_code": "8FW4R9R7+W7"
#             },
#             "rating": 4,
#             "reference": "ChIJe-udXPZx5kcRKURHNFv5BSw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 441,
#             "vicinity": "12 Boulevard de l'H\u00f4pital, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8642974,
#                     "lng": 2.3308142
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8655789302915,
#                         "lng": 2.332153980291502
#                     },
#                     "southwest": {
#                         "lat": 48.8628809697085,
#                         "lng": 2.329456019708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Saint James Albany Paris H\u00f4tel Spa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 400,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108570400659068256718\">Saint James Albany Paris H\u00f4tel Spa</a>"
#                     ],
#                     "photo_reference": "Aap_uEDFT4etky7C9j1M4EfKQqb0WCQc0Flndk-UvEKqo_dNqUz0_FuDSqPVm_-bTcgQ9uFCOU3YGD7ACD25MXXFn5rx8Yi6i2VZe_UzZY1U3ZtAeMrRb_k1Vvop4mTQQfgI1cdgtA29Ctg5x-UCl8keDUToku7M4BigoZHZ4zl1H3Nre3DF",
#                     "width": 600
#                 }
#             ],
#             "place_id": "ChIJ8znTVS5u5kcREq8TmzOICFs",
#             "plus_code": {
#                 "compound_code": "V87J+P8 Paris, France",
#                 "global_code": "8FW4V87J+P8"
#             },
#             "rating": 4,
#             "reference": "ChIJ8znTVS5u5kcREq8TmzOICFs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1075,
#             "vicinity": "202 Rue de Rivoli, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.87110329999999,
#                     "lng": 2.3389728
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8724588802915,
#                         "lng": 2.340112930291502
#                     },
#                     "southwest": {
#                         "lat": 48.8697609197085,
#                         "lng": 2.337414969708499
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Ic\u00f4ne",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1066,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108137830440312077288\">H\u00f4tel Ic\u00f4ne</a>"
#                     ],
#                     "photo_reference": "Aap_uED1dE40XE5UcOcL-ZQlhvr8f8cEhsL898yqk_kJb4bhQTo8_FSM003iR-gTMw3LnltmNApae6C7DJwWZnjWMymFq9RRrhLAXntaiJmKSkd6Wi-8zPlcxFFSmw-HCsnWqjJ9veg9R8h7tK9nh0cbP7YaQnEGCNWdRmFZuo_vet5ddWAN",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJpQvq5Dtu5kcR0COam2f7v_I",
#             "plus_code": {
#                 "compound_code": "V8CQ+CH Paris, France",
#                 "global_code": "8FW4V8CQ+CH"
#             },
#             "rating": 3.7,
#             "reference": "ChIJpQvq5Dtu5kcR0COam2f7v_I",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 141,
#             "vicinity": "4 Rue d'Amboise, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8524547,
#                     "lng": 2.3472064
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8538838802915,
#                         "lng": 2.348601530291502
#                     },
#                     "southwest": {
#                         "lat": 48.8511859197085,
#                         "lng": 2.345903569708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel Esmeralda",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114852001362047630790\">Georgia Hentze</a>"
#                     ],
#                     "photo_reference": "Aap_uEDnB0hgkwkFw9brgPEnbWv-E0kDoUsit3t5jiPClPb3qHHXuz6h1SHCNQmPPEDzM0qx_StF3Q1rTg-2lWTSyTlGodb6bFTEYJBskw6XGJmGXPv2mFaPwf7MUyPVQ8z8uYQhNoWRWaG0hguZvK2YSqOcA6nvgqyIubgjkjs9TNLJaIAr",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJO_g_H-Fx5kcRmaabUHA3dT4",
#             "plus_code": {
#                 "compound_code": "V82W+XV Paris, France",
#                 "global_code": "8FW4V82W+XV"
#             },
#             "rating": 4.1,
#             "reference": "ChIJO_g_H-Fx5kcRmaabUHA3dT4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 147,
#             "vicinity": "4 Rue Saint-Julien le Pauvre, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8530901,
#                     "lng": 2.3447174
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8544403302915,
#                         "lng": 2.346001280291502
#                     },
#                     "southwest": {
#                         "lat": 48.8517423697085,
#                         "lng": 2.343303319708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Albe Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117571951379278191466\">Albe Hotel Saint Michel</a>"
#                     ],
#                     "photo_reference": "Aap_uECj7_9jdOm5UTPAi8u0dqtoz0ITHQnZhmmV5yC1PMQLjyRBGYIRAdSJTS-Cb1aqR_bfd8z27LHcexrCsNFg9KcBvh4WETy4l9uZE7AODPiazoq_oJQjAqGX8q6nZSbME173pxXZXXjomIJbF5J7wBfP0uiEu_EvMu3P19OI7dcBnnu9",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJ8R5-hOBx5kcRsCOdfj8GLeY",
#             "plus_code": {
#                 "compound_code": "V83V+6V Paris, France",
#                 "global_code": "8FW4V83V+6V"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ8R5-hOBx5kcRsCOdfj8GLeY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 332,
#             "vicinity": "1 Rue de la Harpe, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.8499443,
#                     "lng": 2.3462474
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8512737302915,
#                         "lng": 2.347507380291502
#                     },
#                     "southwest": {
#                         "lat": 48.8485757697085,
#                         "lng": 2.344809419708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "Home Latin",
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108547915404801536469\">Jp Homma</a>"
#                     ],
#                     "photo_reference": "Aap_uEB7SbCyOWtxEIpnWOXN59F-J2jTbBBxwFZmHIkHWPEZ_dBqm2zy39noT6wKfAbJ2b2AMUqzhazwUxpy_0BZXcIkWiE91CDJ9oUHlcNAWVGnVrwIRTzuWuoTaw5W_Ja9SU52Oosfe6Lf7oYCGKfJ7g3_uztQiCThUWUwTAbckjJhmu9s",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJMWNDIudx5kcRupjNdNDYKkw",
#             "plus_code": {
#                 "compound_code": "R8XW+XF Paris, France",
#                 "global_code": "8FW4R8XW+XF"
#             },
#             "rating": 3.5,
#             "reference": "ChIJMWNDIudx5kcRupjNdNDYKkw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 286,
#             "vicinity": "15-17 Rue du Sommerard, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.85473870000001,
#                     "lng": 2.3395455
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8561127802915,
#                         "lng": 2.340820530291502
#                     },
#                     "southwest": {
#                         "lat": 48.8534148197085,
#                         "lng": 2.338122569708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel d'Aubusson",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2174,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115702439863948549296\">H\u00f4tel d&#39;Aubusson Paris</a>"
#                     ],
#                     "photo_reference": "Aap_uEAJytHJ7sqh00cHUKve-ANncpBF-FmPHZOwT9jI5j6BWO1nmby7FR6g2eTEhKpTZldSswjp-8C3b6zr-mE3Y6CGo6HTi_mvxbpuELGIyss5lULoFyzYb4nO73zUJcVPhHKgxb6sXC4T17I1_65Vx4Vf-P-oVxy6gopVIA82Ac_z5q9_",
#                     "width": 1739
#                 }
#             ],
#             "place_id": "ChIJk6ztMN9x5kcREpQ8edWOs7E",
#             "plus_code": {
#                 "compound_code": "V83Q+VR Paris, France",
#                 "global_code": "8FW4V83Q+VR"
#             },
#             "rating": 4.7,
#             "reference": "ChIJk6ztMN9x5kcREpQ8edWOs7E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 293,
#             "vicinity": "33 Rue Dauphine, Paris"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 48.85184049999999,
#                     "lng": 2.3448082
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 48.8531470802915,
#                         "lng": 2.346121880291502
#                     },
#                     "southwest": {
#                         "lat": 48.8504491197085,
#                         "lng": 2.343423919708498
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "icon_background_color": "#909CE1",
#             "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet",
#             "name": "H\u00f4tel 4 \u00e9toiles Parc Saint S\u00e9verin Paris 5\u00e8me - Esprit de France",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2362,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107542132357877294567\">H\u00f4tel 4 \u00e9toiles Parc Saint S\u00e9verin Paris 5\u00e8me - Esprit de France</a>"
#                     ],
#                     "photo_reference": "Aap_uECvB3LXsQntnNEsUWkleWaXCJ9yYycR4PjrLCUun9oJtlJbVGN5fQzoladKTIgar4Eyc9EIp5a8iluuZFS8okHgI5Gyr8uT6K8uvvRu0mGVCh9uWDBGPY25wFPtCHlU7ux4alfcOvf5_RdAscUeB4_8XGjQ_woYkLaYpttiQAGDtWb2",
#                     "width": 3776
#                 }
#             ],
#             "place_id": "ChIJ9--kuuBx5kcRojwQ1yEK2cY",
#             "plus_code": {
#                 "compound_code": "V82V+PW Paris, France",
#                 "global_code": "8FW4V82V+PW"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ9--kuuBx5kcRojwQ1yEK2cY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 140,
#             "vicinity": "22 Rue de la Parcheminerie, Paris"
#         }
#     ],
#     "status": "OK"
# }

# %%
len(data['results'])
# Out:
# 20
